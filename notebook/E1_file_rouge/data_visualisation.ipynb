# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sql_and_data/clean.csv")
df
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 609         609  LP002978  Female      No          0      Graduate
# 610         610  LP002979    Male     Yes         3+      Graduate
# 611         611  LP002983    Male     Yes          1      Graduate
# 612         612  LP002984    Male     Yes          2      Graduate
# 613         613  LP002990  Female      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5849                0.0         NaN
# ...

# %% [markdown]
# droping the Unnamed column that appeared when we exported the dataframe earlier in the eda

# %%
df = df.drop("Unnamed: 0" , axis=1)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Visualizing data to get a better understanding of the data

# %%
class DataVisualisation:
    
    def __init__(self,df):
        self.df = df
    
    def info(self): 

    
        #looks if the target is balanced 
        df["Loan_Status"].value_counts().plot.pie()

        #look for the outliers 
        df.plot(kind="box" , subplots=True , figsize=(15,15) , title="Found Outliers")
        
           #

        

        #plot every features of the dataframe to be able to visualize them
        for column in df:
            df[column].value_counts().sort_index(axis=0).plot(kind='bar')
            plt.title(column)
            plt.show()

# %%
test_obj = DataVisualisation(df)
test_obj.info()

# %% [markdown]
# Heatmap used to found correlation between column

# %%
#heatmap to found correlations
class DataVisualisationMultivarie:
    #sns.pairplot(df[df], height = 2)
    sns.heatmap(df.corr(), annot=True)
